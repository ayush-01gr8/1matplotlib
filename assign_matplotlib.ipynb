# %%
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.

# %%
Matplotlib is a popular Python library used for creating static, interactive, and animated visualizations in Python.
It provides a wide range of functionalities for generating various types of plots and charts, making it a powerful tool for data visualization.
five plot
line plot 
bar plot
scatter plot
bar plot 
histogram

# %%
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
Note: Also add title, xlabel, and ylabel to the plot.

# %%
A scatter plot is a type of data visualization that represents individual data points on a two-dimensional plane.
Each data point is represented as a dot, and the position of the dot is determined by the values of two variables (x and y)

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create a scatter plot
plt.scatter(x, y)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')

# Display the plot
plt.show()

# %%
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
The subplot() function in Matplotlib is used to create multiple plots (subplots) within the same figure. It helps in arranging multiple plots in
a grid-like structure, allowing you to visualize and compare different datasets or different aspects of the same dataset.

# %%
import numpy as np 
import matplotlib.pyplot as plt

#For line 1:
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

#For line 2:
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

#For line 3:
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

#For line 4:
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])


plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title('line 1')

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title('line 2')

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title('line 3')

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title('line 4')

plt.tight_layout()

# Display the plots
plt.show()

# %%
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
A bar plot is a type of data visualization that represents categorical data with rectangular bars. The length of each bar is proportional to the
value it represents, making it easy to compare the data across different categories.

Bar plots are used to visualize and compare discrete categories or groups of data. They are particularly useful when you want to show the distribution
of data across different categories, identify trends, or make comparisons between different groups.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create a bar plot
plt.figure(figsize=(8, 6))  # Adjust the figure size
plt.bar(company, profit)


# Add labels and title
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Bar Plot - Company Profits')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 


company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.figure(figsize=(6,4))
plt.barh(company , profit)

plt.xlabel(company)
plt.ylabel(profit)
plt.title('horizontal plotting')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       8 plt.figure(figsize=(6,4))
#       9 plt.barh(company , profit)
# ---> 11 plt.xlabel(company)
#      12 plt.ylabel(profit)
#      13 plt.title('horizontal plotting')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:3019, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    3018 def xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# -> 3019     return gca().set_xlabel(
#    3020         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
#    3021         **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:3513, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3506     x = {
#    3507         'left': 0,
# ...

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
A box plot is a statistical data visualization that provides a concise summary of the distribution of a dataset. 
Box plots are used to visualize the spread and skewness of data, identify potential outliers, compare distributions across different groups,
and gain insights into the central tendency and dispersion of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data=[box1, box2]
labels=['Box1' , 'Box2']

plt.figure(figsize=(8, 6))  # Adjust the figure size
plt.boxplot(data, labels=labels)

# Add labels and title
plt.xlabel('Box')
plt.ylabel('Value')
plt.title('Box Plot')

# Display the plot
plt.show()
